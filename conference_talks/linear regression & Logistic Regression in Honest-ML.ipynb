# %%
from honest_ml.trainer import EvaluateModel
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_regression
import pandas as pd
import numpy as np

reg = LinearRegression()
X, y = make_regression(
    n_samples=2000,  n_features=100,
    n_informative=90,
    random_state=0
)
X = pd.DataFrame(X)
y = pd.Series(y)
num_trials = 200

reg_eval = EvaluateModel("regression", reg, X, y, num_trials)
model_instances = reg_eval.fit_random("random")

# %%
model_instances[0]
# Out:
# {'mse': 1.1133433769099326e-24,
#  'max_error': 2.7284841053187847e-12,
#  'mae': 8.559375430650107e-13,
#  'mask': array([ True,  True,  True, ...,  True,  True, False]),
#  'seed': 0,
#  'hyperparameters': {'copy_X': True,
#   'fit_intercept': True,
#   'n_jobs': None,
#   'normalize': 'deprecated',
#   'positive': False},
#  'coef': array([ 5.79072779e+01,  1.40252058e+01,  1.57580175e+01,  5.53168208e+01,
#          1.19925486e+01,  3.42628481e+01,  1.10986637e-01,  7.96076159e+01,
#          2.22890538e+01,  7.91289665e+01,  3.83760353e+01,  5.52357284e+01,
#          9.67804589e+01,  4.35599865e+01,  8.42750747e+01,  6.95634383e+01,
#          9.53109949e+00,  4.75379375e+01,  5.71323859e+01,  2.85043549e+01,
#          3.91881523e+01,  1.59872116e-14,  6.03016246e+01,  4.76840962e+01,
#          9.46836825e+01,  6.32654984e+01,  2.23239402e+01,  5.32907052e-14,
#         -6.15063556e-14,  2.90937576e+01,  3.08948464e+01,  1.79619898e+01,
#          3.19744231e-14,  1.74399291e+01,  9.96644501e+01,  5.17424060e+01,
#          2.72484541e+01,  6.08116832e+01,  1.53438645e+01,  6.38578198e+01,
#          5.62206935e+01,  2.03283042e+01,  4.22113455e+01,  0.00000000e+00,
#          4.46346728e+01,  1.53014205e+01,  4.25918533e+01,  1.84741111e-13,
#          9.82423457e+01,  6.16571499e+01,  3.01134352e+01,  3.48841732e+01,
#          3.37517527e+01,  7.73374231e+01,  3.17606735e+01,  9.15070228e+00,
#          3.31968971e+01,  3.61498286e+01,  4.02329704e+01,  8.13416338e+01,
#          8.22260107e+00,  3.43231090e+01,  3.03582940e+01,  7.99225683e+01,
#          9.52818241e+01,  7.95138408e+01,  6.75329142e+01,  8.44939748e+00,
#          6.81586443e+00,  5.54556724e+01,  6.33066095e+01,  9.43180493e+01,
#          7.89093470e+01,  6.37247235e+01,  1.27897692e-13,  9.28986421e+01,
#          5.06276429e+01,  4.82875004e+01,  9.43699128e+01,  4.68867080e+01,
#          5.56329083e+01,  4.26325641e-14,  2.66726049e+01,  8.42212736e+01,
#          4.97379915e-14,  7.66669648e+01,  4.78217948e+01,  5.81703506e+01,
#          3.56091173e+01,  8.16485608e+01,  7.19443602e+01,  8.42731949e+00,
#          2.48913560e+01,  7.29449770e+01,  2.60705887e+01,  9.38643378e+01,
#          1.55287421e+01, -7.10542736e-15,  7.50691765e+01,  1.95803069e+01])}

# %%
from honest_ml.visualizer import Visualizer

viz = Visualizer(model_instances, "regression", coef_names=X.columns.tolist())

# %%
viz.visualize_regression()

# %%
viz.visualize_coeficients()

# %%
import warnings
warnings.filterwarnings('ignore')

from honest_ml.trainer import RegressionTrainer, ClassificationTrainer, EvaluateModel
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_regression
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import make_classification
import pandas as pd
import numpy as np

clf = LogisticRegression()
X, y = make_classification(
    n_samples=2000,  n_features=100,
    n_informative=90, n_redundant=2,
    random_state=0
)
X = pd.DataFrame(X)
y = pd.Series(y)
num_trials = 200

clf_eval = EvaluateModel("classification", clf, X, y, num_trials)
model_instances = clf_eval.fit_random("random")

# %%
from honest_ml.visualizer import Visualizer

viz = Visualizer(model_instances, "classification", coef_names=X.columns.tolist())

# %%
viz.visualize_classification()

# %%
viz.visualize_coeficients()
