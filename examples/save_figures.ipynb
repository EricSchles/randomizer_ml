# %%
import warnings
warnings.filterwarnings('ignore')

from honest_ml.trainer import RegressionTrainer, ClassificationTrainer, EvaluateModel
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_regression
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import make_classification
import pandas as pd
import numpy as np

clf = LogisticRegression()
X, y = make_classification(
    n_samples=2000,  n_features=100,
    n_informative=90, n_redundant=2,
    random_state=0
)
X = pd.DataFrame(X)
y = pd.Series(y)
num_trials = 200

clf_eval = EvaluateModel("classification", clf, X, y, num_trials)
model_instances = clf_eval.fit_random("random")

# %%
from honest_ml.visualizer import Visualizer

viz = Visualizer(model_instances, "classification", output_dir="images/", coef_names=X.columns.tolist())

# %%
viz.visualize_classification(save_plots=True, formating="png", bins=len(model_instances))

# %%
viz.visualize_coeficients(save_plots=True, bins=len(model_instances))

# %%
viz.visualize_confusion_matrix(save_plots=True)
